# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/My Drive/Computer Vision Assignment/Code"
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Computer Vision Assignment/Code

# %% [markdown]
# # Install libraries

# %%
# !pip install numpy scipy scikit-learn matplotlib opencv-python sympy

# %% [markdown]
# # Run our pipeline in function ```find_corners```

# %%
# !python "board_detection/evaluate.py"
# Out:
# Finish generating images' paths.
# Total boards: 100, Total incorrect corners: 3, Boards with no mistakes: 97, Average pixel error: 1.2823414230012704
# Total boards: 200, Total incorrect corners: 3, Boards with no mistakes: 197, Average pixel error: 1.2615291044953845
# Total boards: 300, Total incorrect corners: 4, Boards with no mistakes: 296, Average pixel error: 1.2812126779404147
# Total boards: 400, Total incorrect corners: 11, Boards with no mistakes: 392, Average pixel error: 4.8758731151158266
# Total boards: 500, Total incorrect corners: 12, Boards with no mistakes: 491, Average pixel error: 4.147394592917065
# Total boards: 600, Total incorrect corners: 12, Boards with no mistakes: 591, Average pixel error: 3.668895975372507
# Total boards: 700, Total incorrect corners: 12, Boards with no mistakes: 691, Average pixel error: 3.3295713718639237
# Total boards: 800, Total incorrect corners: 13, Boards with no mistakes: 790, Average pixel error: 3.068834632412504
# ...

# %% [markdown]
# # Visualization

# %%
# !python "board_detection/visualize.py"
# Out:
# Visualization images saved to 'visualizations/' directory.
